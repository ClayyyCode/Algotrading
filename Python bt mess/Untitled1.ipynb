# %%
# AV key: GC6EUK3PIEELGNF4
import requests
import csv
import pandas as pd
import io
from datetime import date
from io import StringIO
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

d1 = date.today().strftime("%d%m%Y")


url = "http://localhost:3001/?QQQ"

with requests.get(url, stream=True) as r:
        QQQ = (pd.read_csv(StringIO(r.text)))

# %%
figure(figsize=(16,12), dpi=120)
plt.figure().set_size_inches(20,10)
plt.figure().set_figwidth(40)
plt.figure().set_figheight(10)

# %%
plt.plot(QQQ.iloc[:,0], QQQ.iloc[:,4])
plt.plot(QQQ.iloc[:,0], QQQ.iloc[:,5])
plt.plot(QQQ.iloc[:,0], QQQ.iloc[:,6])
plt.plot(QQQ.iloc[:,0], QQQ.iloc[:,7])
plt.plot(QQQ.iloc[:,0], QQQ.iloc[:,8])
plt.ylabel("price")
plt.xlabel("date")

plt.show()
